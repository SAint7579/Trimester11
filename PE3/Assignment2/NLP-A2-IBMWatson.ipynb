# %%
#Speech to text Conversion Using IBM Watson API- File type-Audio-wac file
import json
import os
from os.path import join, dirname
from ibm_watson import SpeechToTextV1
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator

authenticator = IAMAuthenticator('xIYhXtY6yerL5RaJtcIWeZsRUEhr2Lg4QtJl8ewdWdFJ')
speech_to_text = SpeechToTextV1(
    authenticator=authenticator
)

speech_to_text.set_service_url('https://api.eu-gb.speech-to-text.watson.cloud.ibm.com/instances/6fedbb60-6c90-4d7c-bcad-2d11f3e4b917')

with open(os.path.join(os.path.dirname(os.path.abspath("__file__")), './.', 'audio-file.flac'),
               'rb') as audio_file:
    speech_recognition_results = speech_to_text.recognize(
        audio=audio_file,
        content_type='audio/flac',
        word_alternatives_threshold=0.9,
        keywords=['colorado', 'tornado', 'tornadoes'],
        keywords_threshold=0.5
    ).get_result()
print(json.dumps(speech_recognition_results, indent=2))
# Out:
# {
#   "result_index": 0,
#   "results": [
#     {
#       "final": true,
#       "alternatives": [
#         {
#           "transcript": "several tornadoes touched down as a line of severe thunderstorms swept through Colorado on Sunday ",
#           "confidence": 0.94
#         }
#       ],
#       "word_alternatives": [
#         {
#           "start_time": 1.0,
#           "end_time": 1.52,
#           "alternatives": [
#             {
#               "word": "several",
#               "confidence": 0.98
#             }
#           ]
#         },
#         {
#           "start_time": 1.52,
#           "end_time": 2.15,
#           "alternatives": [
#             {
#               "word": "tornadoes",
#               "confidence": 1.0
#             }
#           ]
#         },
#         {
#           "start_time": 2.15,
#           "end_time": 2.54,
#           "alternatives": [
#             {
#               "word": "touched",
#               "confidence": 0.9
#             }
#           ]
#         },
#         {
#           "start_time": 2.54,
#           "end_time": 2.82,
#           "alternatives": [
#             {
#               "word": "down",
#               "confidence": 1.0
#             }
#           ]
#         },
#         {
#           "start_time": 2.82,
#           "end_time": 2.92,
#           "alternatives": [
#             {
#               "word": "as",
#               "confidence": 1.0
#             }
#           ]
#         },
#         {
#           "start_time": 2.92,
#           "end_time": 3.0,
#           "alternatives": [
#             {
#               "word": "a",
#               "confidence": 1.0
#             }
#           ]
#         },
#         {
#           "start_time": 3.0,
#           "end_time": 3.3,
#           "alternatives": [
#             {
#               "word": "line",
#               "confidence": 1.0
#             }
#           ]
#         },
#         {
#           "start_time": 3.3,
#           "end_time": 3.39,
#           "alternatives": [
#             {
#               "word": "of",
#               "confidence": 1.0
#             }
#           ]
#         },
#         {
#           "start_time": 3.39,
#           "end_time": 3.77,
#           "alternatives": [
#             {
#               "word": "severe",
#               "confidence": 1.0
#             }
#           ]
#         },
#         {
#           "start_time": 3.77,
#           "end_time": 4.51,
#           "alternatives": [
#             {
#               "word": "thunderstorms",
#               "confidence": 1.0
#             }
#           ]
#         },
#         {
#           "start_time": 4.51,
#           "end_time": 4.79,
#           "alternatives": [
#             {
#               "word": "swept",
#               "confidence": 1.0
#             }
#           ]
#         },
#         {
#           "start_time": 4.79,
#           "end_time": 4.95,
#           "alternatives": [
#             {
#               "word": "through",
#               "confidence": 1.0
#             }
#           ]
#         },
#         {
#           "start_time": 4.95,
#           "end_time": 5.6,
#           "alternatives": [
#             {
#               "word": "Colorado",
#               "confidence": 0.97
#             }
#           ]
#         },
#         {
#           "start_time": 5.6,
#           "end_time": 5.73,
#           "alternatives": [
#             {
#               "word": "on",
#               "confidence": 0.98
#             }
#           ]
#         },
#         {
#           "start_time": 5.73,
#           "end_time": 6.36,
#           "alternatives": [
#             {
#               "word": "Sunday",
#               "confidence": 0.98
#             }
#           ]
#         }
#       ],
#       "keywords_result": {
#         "colorado": [
#           {
#             "start_time": 4.95,
#             "end_time": 5.6,
#             "confidence": 0.97,
#             "normalized_text": "Colorado"
#           }
#         ],
#         "tornadoes": [
#           {
#             "start_time": 1.52,
#             "end_time": 2.15,
#             "confidence": 1.0,
#             "normalized_text": "tornadoes"
#           }
#         ]
#       }
#     }
#   ]
# }

# %%
#Speech to text Conversion Using IBM Watson API- File type-Audio-mp3 file
import json
import os
from os.path import join, dirname
from ibm_watson import SpeechToTextV1
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator

authenticator = IAMAuthenticator('xIYhXtY6yerL5RaJtcIWeZsRUEhr2Lg4QtJl8ewdWdFJ')
speech_to_text = SpeechToTextV1(
    authenticator=authenticator
)

speech_to_text.set_service_url('https://api.eu-gb.speech-to-text.watson.cloud.ibm.com/instances/6fedbb60-6c90-4d7c-bcad-2d11f3e4b917')

with open(os.path.join(os.path.dirname(os.path.abspath("__file__")), './.', 'welcom12.mp3'),
               'rb') as audio_file:
    speech_recognition_results = speech_to_text.recognize(
        audio=audio_file,
        content_type='audio/mp3',
        word_alternatives_threshold=0.9,
        keywords=['welcome', 'this'],
        keywords_threshold=0.5
    ).get_result()
print(speech_recognition_results)
print(json.dumps(speech_recognition_results, indent=2))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-127a0762a1d0> in <module>
#      13 speech_to_text.set_service_url('https://api.eu-gb.speech-to-text.watson.cloud.ibm.com/instances/6fedbb60-6c90-4d7c-bcad-2d11f3e4b917')
#      14
# ---> 15 with open(os.path.join(os.path.dirname(os.path.abspath("__file__")), './.', 'welcom12.mp3'),
#      16                'rb') as audio_file:
#      17     speech_recognition_results = speech_to_text.recognize(
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\vishw\\OneDrive\\Desktop\\T11\\PE3\\Assignment2\\./.\\welcom12.mp3'
