# %% [markdown]
# ## CCNLP Assignment 3

# %% [markdown]
# Vishwa Mohan Singh
# PA10

# %% [markdown]
# ## Categories

# %%
import json
from ibm_watson import NaturalLanguageUnderstandingV1
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator

# Categories Features

from ibm_watson.natural_language_understanding_v1 import Features, CategoriesOptions

authenticator = IAMAuthenticator('qkeY9fOxU9_ydnlm_meloySvMVi7DqNiTW8OdmCs9xP2')
natural_language_understanding = NaturalLanguageUnderstandingV1(
    version='2019-07-12',
    authenticator=authenticator
)

natural_language_understanding.set_service_url('https://api.eu-gb.natural-language-understanding.watson.cloud.ibm.com/instances/bb51e465-056f-4157-a2e1-31ee75f9faef')

response = natural_language_understanding.analyze(
    url='https://towardsdatascience.com/chest-x-rays-pneumonia-detection-using-convolutional-neural-network-63d6ec2d1dee',
    features=Features(categories=CategoriesOptions(limit=5))).get_result()

print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_units": 1,
#     "text_characters": 3461,
#     "features": 1
#   },
#   "retrieved_url": "https://towardsdatascience.com/chest-x-rays-pneumonia-detection-using-convolutional-neural-network-63d6ec2d1dee?gi=dfbd15dcf7b5",
#   "language": "en",
#   "categories": [
#     {
#       "score": 0.807066,
#       "label": "/technology and computing/hardware/computer components"
#     },
#     {
#       "score": 0.783157,
#       "label": "/health and fitness/disease"
#     },
#     {
#       "score": 0.683885,
#       "label": "/health and fitness/disease/asthma"
#     },
#     {
#       "score": 0.627278,
#       "label": "/technology and computing/hardware/computer"
#     },
#     {
#       "score": 0.606899,
#       "label": "/technology and computing/hardware/computer peripherals/computer monitors"
#     }
#   ]
# }

# %% [markdown]
# ## Concept

# %%
# Concepts Features

from ibm_watson.natural_language_understanding_v1 import Features, ConceptsOptions
 
response = natural_language_understanding.analyze(
    url='https://towardsdatascience.com/chest-x-rays-pneumonia-detection-using-convolutional-neural-network-63d6ec2d1dee',
    features=Features(concepts=ConceptsOptions(limit=3))).get_result()

print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_units": 1,
#     "text_characters": 3461,
#     "features": 1
#   },
#   "retrieved_url": "https://towardsdatascience.com/chest-x-rays-pneumonia-detection-using-convolutional-neural-network-63d6ec2d1dee?gi=bbcad9a3f08a",
#   "language": "en",
#   "concepts": [
#     {
#       "text": "X-ray",
#       "relevance": 0.946808,
#       "dbpedia_resource": "http://dbpedia.org/resource/X-ray"
#     },
#     {
#       "text": "Inflammation",
#       "relevance": 0.939761,
#       "dbpedia_resource": "http://dbpedia.org/resource/Inflammation"
#     },
#     {
#       "text": "Pneumonia",
#       "relevance": 0.877324,
#       "dbpedia_resource": "http://dbpedia.org/resource/Pneumonia"
#     }
#   ]
# }

# %% [markdown]
# ## Emotion

# %%
# Emotions Features
from ibm_watson.natural_language_understanding_v1 import Features, EmotionOptions

response = natural_language_understanding.analyze(
    url="https://www.quora.com/Was-Alexander-Hamilton-a-good-person-in-real-life",
    features=Features(emotion=EmotionOptions(targets=['Alexander', "Aaron Burr"]))).get_result()

print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_units": 1,
#     "text_characters": 62,
#     "features": 1
#   },
#   "retrieved_url": "https://www.quora.com/Was-Alexander-Hamilton-a-good-person-in-real-life",
#   "language": "en",
#   "emotion": {
#     "targets": [
#       {
#         "text": "Alexander",
#         "emotion": {
#           "sadness": 0.239716,
#           "joy": 0.646972,
#           "fear": 0.030182,
#           "disgust": 0.026012,
#           "anger": 0.030549
#         }
#       }
#     ],
#     "document": {
#       "emotion": {
#         "sadness": 0.247848,
#         "joy": 0.60702,
#         "fear": 0.033948,
#         "disgust": 0.031578,
#         "anger": 0.038969
#       }
#     }
#   }
# }

# %% [markdown]
# ## Entity

# %%
# Entities Features 
from ibm_watson.natural_language_understanding_v1 import Features, EntitiesOptions

response = natural_language_understanding.analyze(
    url='https://towardsdatascience.com/chest-x-rays-pneumonia-detection-using-convolutional-neural-network-63d6ec2d1dee',
    features=Features(entities=EntitiesOptions(sentiment=True,limit=5))).get_result()

print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_units": 1,
#     "text_characters": 3461,
#     "features": 1
#   },
#   "retrieved_url": "https://towardsdatascience.com/chest-x-rays-pneumonia-detection-using-convolutional-neural-network-63d6ec2d1dee?gi=b873091adcaf",
#   "language": "en",
#   "entities": [
#     {
#       "type": "Company",
#       "text": "Convolutional Neural Network",
#       "sentiment": {
#         "score": -0.832257,
#         "label": "negative"
#       },
#       "relevance": 0.953262,
#       "count": 1,
#       "confidence": 0.220434
#     },
#     {
#       "type": "HealthCondition",
#       "text": "lung inflammation",
#       "sentiment": {
#         "score": -0.982087,
#         "label": "negative"
#       },
#       "relevance": 0.897989,
#       "count": 1,
#       "confidence": 0.462723
#     },
#     {
#       "type": "HealthCondition",
#       "text": "Pneumonia",
#       "sentiment": {
#         "score": -0.982087,
#         "label": "negative"
#       },
#       "relevance": 0.874658,
#       "count": 3,
#       "confidence": 0.999916
#     },
#     {
#       "type": "HealthCondition",
#       "text": "pneumonia lung",
#       "sentiment": {
#         "score": -0.720104,
#         "label": "negative"
#       },
#       "relevance": 0.751371,
#       "count": 1,
#       "confidence": 0.809086
#     },
#     {
#       "type": "Company",
#       "text": "CNN",
#       "sentiment": {
#         "score": -0.832257,
#         "label": "negative"
#       },
#       "relevance": 0.548987,
#       "disambiguation": {
#         "subtype": [
#           "Broadcast",
#           "AwardWinner",
#           "RadioNetwork",
#           "TVNetwork"
#         ],
#         "name": "CNN",
#         "dbpedia_resource": "http://dbpedia.org/resource/CNN"
#       },
#       "count": 2,
#       "confidence": 0.935134
#     }
#   ]
# }

# %% [markdown]
# ## Keywords

# %%
# Keywprds Features
from ibm_watson.natural_language_understanding_v1 import Features, KeywordsOptions

response = natural_language_understanding.analyze(
    url='https://towardsdatascience.com/chest-x-rays-pneumonia-detection-using-convolutional-neural-network-63d6ec2d1dee',
    features=Features(keywords=KeywordsOptions(sentiment=True,emotion=True,limit=2))).get_result()

print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_units": 1,
#     "text_characters": 3461,
#     "features": 1
#   },
#   "retrieved_url": "https://towardsdatascience.com/chest-x-rays-pneumonia-detection-using-convolutional-neural-network-63d6ec2d1dee?gi=9bb4a299c523",
#   "language": "en",
#   "keywords": [
#     {
#       "text": "content of the mini-project",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "relevance": 0.68447,
#       "emotion": {
#         "sadness": 0.045376,
#         "joy": 0.670817,
#         "fear": 0.036722,
#         "disgust": 0.018289,
#         "anger": 0.025769
#       },
#       "count": 1
#     },
#     {
#       "text": "analysis of model accuracy",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "relevance": 0.624179,
#       "emotion": {
#         "sadness": 0.446687,
#         "joy": 0.108923,
#         "fear": 0.026191,
#         "disgust": 0.024695,
#         "anger": 0.018184
#       },
#       "count": 1
#     }
#   ]
# }

# %% [markdown]
# ## Metadata

# %%
#Metadata Feature
from ibm_watson.natural_language_understanding_v1 import Features, MetadataOptions

response = natural_language_understanding.analyze(
    url='www.ibm.com',
    features=Features(metadata=MetadataOptions())).get_result()

print(json.dumps(response, indent=2))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-11-b55ff65bcbc9> in <module>
#       1 #Metadata Feature
# ----> 2 from ibm_watson.natural_language_understanding_v1 import Features, MetadataOptions
#       3
#       4 response = natural_language_understanding.analyze(
#       5     url='www.ibm.com',
#
# ImportError: cannot import name 'MetadataOptions' from 'ibm_watson.natural_language_understanding_v1' (C:\Users\vishw\anaconda3\lib\site-packages\ibm_watson\natural_language_understanding_v1.py)

# %% [markdown]
# ## Relation

# %%
# Relations Features 
from ibm_watson.natural_language_understanding_v1 import Features, RelationsOptions

response = natural_language_understanding.analyze(
    url='https://towardsdatascience.com/chest-x-rays-pneumonia-detection-using-convolutional-neural-network-63d6ec2d1dee',
    features=Features(relations=RelationsOptions())).get_result()

print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_units": 1,
#     "text_characters": 3461,
#     "features": 1
#   },
#   "retrieved_url": "https://towardsdatascience.com/chest-x-rays-pneumonia-detection-using-convolutional-neural-network-63d6ec2d1dee?gi=68284b254453",
#   "relations": [
#     {
#       "type": "partOf",
#       "sentence": "This experiment leveraging the data from Kaggle repository titled Chest X-Ray Images (Pneumonia).",
#       "score": 0.411188,
#       "arguments": [
#         {
#           "text": "Kaggle repository",
#           "location": [
#             801,
#             818
#           ],
#           "entities": [
#             {
#               "type": "Organization",
#               "text": "Kaggle repository",
#               "disambiguation": {
#                 "subtype": [
#                   "Commercial"
#                 ]
#               }
#             }
#           ]
#         },
#         {
#           "text": "Chest X-Ray Images",
#           "location": [
#             826,
#             844
#           ],
#           "entities": [
#             {
#               "type": "Organization",
#               "text": "Chest X-Ray Images",
#               "disambiguation": {
#                 "subtype": [
#                   "Commercial"
#                 ]
#               }
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "type": "hasAttribute",
#       "sentence": "The accuracy of the trained model reaches 81.25% as can be seen in the figure below: Now the model is ready to make a prediction, in which the code below allows the user to input an image to determine whether the x-ray image is diagnosed with pneumonia.",
#       "score": 0.674427,
#       "arguments": [
#         {
#           "text": "user",
#           "location": [
#             2560,
#             2564
#           ],
#           "entities": [
#             {
#               "type": "Person",
#               "text": "user"
#             }
#           ]
#         },
#         {
#           "text": "pneumonia",
#           "location": [
#             2638,
#             2647
#           ],
#           "entities": [
#             {
#               "type": "HealthCondition",
#               "text": "lung inflammation"
#             }
#           ]
#         }
#       ]
#     }
#   ],
#   "language": "en"
# }

# %% [markdown]
# ## Semantic Analysis

# %%
# Semantic Analysis
from ibm_watson.natural_language_understanding_v1 import Features, SemanticRolesOptions

response = natural_language_understanding.analyze(
    text='IBM has one of the largest workforces in the world',
    features=Features(semantic_roles=SemanticRolesOptions())).get_result()

print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_units": 1,
#     "text_characters": 50,
#     "features": 1
#   },
#   "semantic_roles": [
#     {
#       "subject": {
#         "text": "IBM"
#       },
#       "sentence": "IBM has one of the largest workforces in the world",
#       "object": {
#         "text": "one of the largest workforces in the world"
#       },
#       "action": {
#         "verb": {
#           "text": "have",
#           "tense": "present"
#         },
#         "text": "has",
#         "normalized": "have"
#       }
#     }
#   ],
#   "language": "en"
# }

# %% [markdown]
# ## Syntax Analysis

# %%
# Syntax Analysis
from ibm_watson.natural_language_understanding_v1 import Features, SyntaxOptions, SyntaxOptionsTokens

response = natural_language_understanding.analyze(
    text='The quick brown fox jumps over the lazy dog!',
    features=Features(
      syntax=SyntaxOptions(
        sentences=True,
        tokens=SyntaxOptionsTokens(
          lemma=True,
          part_of_speech=True,
        )))).get_result()

print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_units": 1,
#     "text_characters": 44,
#     "features": 1
#   },
#   "syntax": {
#     "tokens": [
#       {
#         "text": "The",
#         "part_of_speech": "DET",
#         "location": [
#           0,
#           3
#         ],
#         "lemma": "the"
#       },
#       {
#         "text": "quick",
#         "part_of_speech": "ADJ",
#         "location": [
#           4,
#           9
#         ],
#         "lemma": "quick"
#       },
#       {
#         "text": "brown",
#         "part_of_speech": "ADJ",
#         "location": [
#           10,
#           15
#         ],
#         "lemma": "brown"
#       },
#       {
#         "text": "fox",
#         "part_of_speech": "NOUN",
#         "location": [
#           16,
#           19
#         ],
#         "lemma": "fox"
#       },
#       {
#         "text": "jumps",
#         "part_of_speech": "NOUN",
#         "location": [
#           20,
#           25
#         ],
#         "lemma": "jump"
#       },
#       {
#         "text": "over",
#         "part_of_speech": "ADP",
#         "location": [
#           26,
#           30
#         ],
#         "lemma": "over"
#       },
#       {
#         "text": "the",
#         "part_of_speech": "DET",
#         "location": [
#           31,
#           34
#         ],
#         "lemma": "the"
#       },
#       {
#         "text": "lazy",
#         "part_of_speech": "ADJ",
#         "location": [
#           35,
#           39
#         ],
#         "lemma": "lazy"
#       },
#       {
#         "text": "dog",
#         "part_of_speech": "NOUN",
#         "location": [
#           40,
#           43
#         ],
#         "lemma": "dog"
#       },
#       {
#         "text": "!",
#         "part_of_speech": "PUNCT",
#         "location": [
#           43,
#           44
#         ]
#       }
#     ],
#     "sentences": [
#       {
#         "text": "The quick brown fox jumps over the lazy dog!",
#         "location": [
#           0,
#           44
#         ]
#       }
#     ]
#   },
#   "language": "en"
# }
